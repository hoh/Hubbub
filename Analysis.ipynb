# %%
from IPython.display import HTML
HTML('''<h1>Table of Contents</h1>

<ol>
    <li><a href='#Comparing-real-and-dummy-delays'>Comparison of delays between real and dummies</a></li>
</ol>
<hr/>''')
# Out:
# <h1>Table of Contents</h1>
#
# <ol>
#     <li><a href='#Comparing-real-and-dummy-delays'>Comparison of delays between real and dummies</a></li>
# </ol>
# <hr/>

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Large plots
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 16, 9

# %%
import numpy as np
import pandas as pd

# %%
from hubbub.generator.generator import Simulator
from hubbub.generator.heartbeat import HeartBeatSimulator
from hubbub.datasets.simulations import simple_log, SIMPLE_LOG as SIMPLE_LOG_SAMPLE
# Out:
# Warning: This tool is designed for Python 3.

# %%
#SIMPLE_LOG = SIMPLE_LOG_SAMPLE
SIMPLE_LOG_SAMPLE
# Out:
# [(datetime.datetime(2000, 1, 1, 0, 1, 1, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 2, 9, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 3, 2, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 4, 8, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 5, 3, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 6, 7, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 7, 4, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 8, 6, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 9, 5, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 10, 0, 123456), 10)]

# %%
# Generating "real" messages dataset:
SIMPLE_LOG = simple_log(n=2000)
SIMPLE_LOG[:10]
# Out:
# [(datetime.datetime(2000, 1, 1, 0, 0, 13, 899879), 10),
#  (datetime.datetime(2000, 1, 1, 0, 3, 23, 384584), 10),
#  (datetime.datetime(2000, 1, 1, 0, 4, 25, 666098), 10),
#  (datetime.datetime(2000, 1, 1, 0, 6, 7, 365179), 10),
#  (datetime.datetime(2000, 1, 1, 0, 6, 34, 725263), 10),
#  (datetime.datetime(2000, 1, 1, 0, 6, 59, 449241), 10),
#  (datetime.datetime(2000, 1, 1, 0, 7, 35, 259541), 10),
#  (datetime.datetime(2000, 1, 1, 0, 8, 21, 921992), 10),
#  (datetime.datetime(2000, 1, 1, 0, 8, 44, 261884), 10),
#  (datetime.datetime(2000, 1, 1, 0, 10, 7, 105935), 10)]

# %% [markdown]
# # Running simulator

# %%
result_sm = Simulator(SIMPLE_LOG).run()
results_HB = [
    HeartBeatSimulator(SIMPLE_LOG).run() for i in xrange(5)
#    HeartBeatSimulator(SIMPLE_LOG).run(delay=lambda: 5) for i in xrange(10)
    ]

results_HB[0][:10]
# Out:
# [(datetime.datetime(2000, 1, 1, 0, 0), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 3, 331629), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 7, 376890), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 7, 629040), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 8, 954074), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 10, 713615), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 11, 624194), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 14, 459435), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 15, 296170), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 15, 832711), 10)]

# %% [markdown]
# ## Converting results to timestamps for plotting:

# %%
import time
def timestamp(n):
    unix_time = time.mktime(n.timetuple()) + n.microsecond/1000000.
    return unix_time

# %%
r_real = pd.DataFrame(
    [(0, timestamp(i[0]), 'SIMPLE_LOG') for i in SIMPLE_LOG],
    columns=('dummy', 'timestamp', 'source'),
    )
r_real
# Out:
#     dummy     timestamp      source
# 0       0  9.466812e+08  SIMPLE_LOG
# 1       0  9.466814e+08  SIMPLE_LOG
# 2       0  9.466815e+08  SIMPLE_LOG
# 3       0  9.466816e+08  SIMPLE_LOG
# 4       0  9.466816e+08  SIMPLE_LOG
# 5       0  9.466816e+08  SIMPLE_LOG
# 6       0  9.466817e+08  SIMPLE_LOG
# 7       0  9.466817e+08  SIMPLE_LOG
# 8       0  9.466817e+08  SIMPLE_LOG
# 9       0  9.466818e+08  SIMPLE_LOG
# 10      0  9.466818e+08  SIMPLE_LOG
# 11      0  9.466819e+08  SIMPLE_LOG
# 12      0  9.466820e+08  SIMPLE_LOG
# 13      0  9.466820e+08  SIMPLE_LOG
# 14      0  9.466820e+08  SIMPLE_LOG
# 15      0  9.466820e+08  SIMPLE_LOG
# 16      0  9.466820e+08  SIMPLE_LOG
# 17      0  9.466820e+08  SIMPLE_LOG
# 18      0  9.466820e+08  SIMPLE_LOG
# 19      0  9.466821e+08  SIMPLE_LOG
# 20      0  9.466823e+08  SIMPLE_LOG
# 21      0  9.466824e+08  SIMPLE_LOG
# 22      0  9.466825e+08  SIMPLE_LOG
# 23      0  9.466825e+08  SIMPLE_LOG
# 24      0  9.466825e+08  SIMPLE_LOG
# 25      0  9.466827e+08  SIMPLE_LOG
# 26      0  9.466827e+08  SIMPLE_LOG
# 27      0  9.466827e+08  SIMPLE_LOG
# 28      0  9.466827e+08  SIMPLE_LOG
# 29      0  9.466828e+08  SIMPLE_LOG
# 30      0  9.466828e+08  SIMPLE_LOG
# 31      0  9.466828e+08  SIMPLE_LOG
# 32      0  9.466828e+08  SIMPLE_LOG
# 33      0  9.466828e+08  SIMPLE_LOG
# 34      0  9.466829e+08  SIMPLE_LOG
# 35      0  9.466829e+08  SIMPLE_LOG
# 36      0  9.466830e+08  SIMPLE_LOG
# 37      0  9.466830e+08  SIMPLE_LOG
# 38      0  9.466830e+08  SIMPLE_LOG
# 39      0  9.466831e+08  SIMPLE_LOG
# 40      0  9.466831e+08  SIMPLE_LOG
# 41      0  9.466831e+08  SIMPLE_LOG
# 42      0  9.466832e+08  SIMPLE_LOG
# 43      0  9.466832e+08  SIMPLE_LOG
# 44      0  9.466832e+08  SIMPLE_LOG
# 45      0  9.466833e+08  SIMPLE_LOG
# 46      0  9.466834e+08  SIMPLE_LOG
# 47      0  9.466834e+08  SIMPLE_LOG
# 48      0  9.466835e+08  SIMPLE_LOG
# 49      0  9.466835e+08  SIMPLE_LOG
# 50      0  9.466836e+08  SIMPLE_LOG
# 51      0  9.466836e+08  SIMPLE_LOG
# 52      0  9.466837e+08  SIMPLE_LOG
# 53      0  9.466837e+08  SIMPLE_LOG
# 54      0  9.466837e+08  SIMPLE_LOG
# 55      0  9.466837e+08  SIMPLE_LOG
# 56      0  9.466837e+08  SIMPLE_LOG
# 57      0  9.466837e+08  SIMPLE_LOG
# 58      0  9.466838e+08  SIMPLE_LOG
# 59      0  9.466839e+08  SIMPLE_LOG
#       ...           ...         ...
#
# [2000 rows x 3 columns]

# %%
r_dummyHB = [
    pd.DataFrame(
        [(1, timestamp(i[0]), 'HB{}'.format(index)) for i in r],
        columns=('dummy', 'timestamp', 'source'),
        )
    for index, r in enumerate(results_HB)
    ]
r_dummyHB[0]
# Out:
#     dummy     timestamp source
# 0       1  9.466812e+08    HB0
# 1       1  9.466812e+08    HB0
# 2       1  9.466812e+08    HB0
# 3       1  9.466812e+08    HB0
# 4       1  9.466812e+08    HB0
# 5       1  9.466812e+08    HB0
# 6       1  9.466812e+08    HB0
# 7       1  9.466812e+08    HB0
# 8       1  9.466812e+08    HB0
# 9       1  9.466812e+08    HB0
# 10      1  9.466812e+08    HB0
# 11      1  9.466812e+08    HB0
# 12      1  9.466812e+08    HB0
# 13      1  9.466812e+08    HB0
# 14      1  9.466812e+08    HB0
# 15      1  9.466812e+08    HB0
# 16      1  9.466812e+08    HB0
# 17      1  9.466812e+08    HB0
# 18      1  9.466812e+08    HB0
# 19      1  9.466812e+08    HB0
# 20      1  9.466812e+08    HB0
# 21      1  9.466812e+08    HB0
# 22      1  9.466812e+08    HB0
# 23      1  9.466812e+08    HB0
# 24      1  9.466812e+08    HB0
# 25      1  9.466812e+08    HB0
# 26      1  9.466812e+08    HB0
# 27      1  9.466812e+08    HB0
# 28      1  9.466812e+08    HB0
# 29      1  9.466813e+08    HB0
# 30      1  9.466813e+08    HB0
# 31      1  9.466813e+08    HB0
# 32      1  9.466813e+08    HB0
# 33      1  9.466813e+08    HB0
# 34      1  9.466813e+08    HB0
# 35      1  9.466813e+08    HB0
# 36      1  9.466813e+08    HB0
# 37      1  9.466813e+08    HB0
# 38      1  9.466813e+08    HB0
# 39      1  9.466813e+08    HB0
# 40      1  9.466813e+08    HB0
# 41      1  9.466813e+08    HB0
# 42      1  9.466813e+08    HB0
# 43      1  9.466813e+08    HB0
# 44      1  9.466813e+08    HB0
# 45      1  9.466813e+08    HB0
# 46      1  9.466813e+08    HB0
# 47      1  9.466813e+08    HB0
# 48      1  9.466813e+08    HB0
# 49      1  9.466813e+08    HB0
# 50      1  9.466813e+08    HB0
# 51      1  9.466813e+08    HB0
# 52      1  9.466813e+08    HB0
# 53      1  9.466813e+08    HB0
# 54      1  9.466813e+08    HB0
# 55      1  9.466813e+08    HB0
# 56      1  9.466813e+08    HB0
# 57      1  9.466813e+08    HB0
# 58      1  9.466813e+08    HB0
# 59      1  9.466813e+08    HB0
#       ...           ...    ...
#
# [51817 rows x 3 columns]

# %% [markdown]
# # Analyzing delays

# %% [markdown]
# ## Plotting

# %%
r = r_dummyHB[0]
figure()
plot(r['timestamp'][:100].diff(), 'o-')
show()

figure()
for r in r_dummyHB:
    plot(r['timestamp'][:100].diff(), 'o')
show()

# %%
r_mixed = [
    pd.concat((r_real, r))
    for r in r_dummyHB
]
for r in r_mixed:
    r.sort('timestamp', inplace=True)
    r['before'] = r['timestamp'].diff()
    r['after'] = -r['timestamp'].diff(periods=-1)

r_mixed[0].head(10)
# Out:
#    dummy     timestamp      source    before     after
# 0      1  9.466812e+08         HB0       NaN  3.331629
# 1      1  9.466812e+08         HB0  3.331629  4.045261
# 2      1  9.466812e+08         HB0  4.045261  0.252150
# 3      1  9.466812e+08         HB0  0.252150  1.325034
# 4      1  9.466812e+08         HB0  1.325034  1.759541
# 5      1  9.466812e+08         HB0  1.759541  0.910579
# 6      1  9.466812e+08         HB0  0.910579  2.275685
# 0      0  9.466812e+08  SIMPLE_LOG  2.275685  0.559556
# 7      1  9.466812e+08         HB0  0.559556  0.836735
# 8      1  9.466812e+08         HB0  0.836735  0.536541
#
# [10 rows x 5 columns]

# %% [markdown]
# ## Comparing real and dummy delays

# %%
print r_real['timestamp'][0]
r = r_mixed[0]
plot(r['before'])
r[r['dummy'] == 0].head(10)
# Out:
# 946681213.9
#    dummy     timestamp      source    before     after
# 0      0  9.466812e+08  SIMPLE_LOG  2.275685  0.559556
# 1      0  9.466814e+08  SIMPLE_LOG  1.594244  0.234788
# 2      0  9.466815e+08  SIMPLE_LOG  0.380456  1.993533
# 3      0  9.466816e+08  SIMPLE_LOG  0.721418  0.105434
# 4      0  9.466816e+08  SIMPLE_LOG  1.293210  0.450494
# 5      0  9.466816e+08  SIMPLE_LOG  3.703413  0.426620
# 6      0  9.466817e+08  SIMPLE_LOG  3.136036  0.208789
# 7      0  9.466817e+08  SIMPLE_LOG  0.367304  0.407943
# 8      0  9.466817e+08  SIMPLE_LOG  0.652515  0.267943
# 9      0  9.466818e+08  SIMPLE_LOG  1.548884  0.064073
#
# [10 rows x 5 columns]

# %% [markdown]
# ## Delay before

# %%
# Average delay

if False:
    for r in r_mixed:
        print 'all  mean', r['before'].mean()
        print 'all  std ', r['before'].std()
        print 'dumm mean', r[r['dummy'] == 1]['before'].mean()
        print 'dumm std ', r[r['dummy'] == 1]['before'].std()
        print 'real mean', r[r['dummy'] == 0]['before'].mean()
        print 'real std ', r[r['dummy'] == 0]['before'].std()
        print

bar(
    range(0, len(r_mixed)*3, 3), 
    [r['before'].mean() for r in r_mixed], 
    yerr=[r['before'].std() for r in r_mixed], 
    color='g',
    )
    
bar(
    range(1, len(r_mixed)*3, 3), 
    [r[r['dummy'] == 1]['before'].mean() for r in r_mixed], 
    yerr=[r[r['dummy'] == 1]['before'].std() for r in r_mixed], 
    color='y',
    )

bar(
    range(2, len(r_mixed)*3, 3), 
    [r[r['dummy'] == 0]['before'].mean() for r in r_mixed], 
    yerr=[r[r['dummy'] == 0]['before'].std() for r in r_mixed], 
    color='r',
    )
# Out:
# <Container object of 5 artists>

# %% [markdown]
# ## Delay After

# %%
# Average delay

if False:
    for r in r_mixed:
        print 'all  mean', r['after'].mean()
        print 'all  std ', r['after'].std()
        print 'dumm mean', r[r['dummy'] == 1]['after'].mean()
        print 'dumm std ', r[r['dummy'] == 1]['after'].std()
        print 'real mean', r[r['dummy'] == 0]['after'].mean()
        print 'real std ', r[r['dummy'] == 0]['after'].std()
        print

bar(
    range(0, len(r_mixed)*3, 3), 
    [r['after'].mean() for r in r_mixed], 
    yerr=[r['after'].std() for r in r_mixed], 
    color='g',
    )
    
bar(
    range(1, len(r_mixed)*3, 3), 
    [r[r['dummy'] == 1]['after'].mean() for r in r_mixed], 
    yerr=[r[r['dummy'] == 1]['after'].std() for r in r_mixed], 
    color='y',
    )

bar(
    range(2, len(r_mixed)*3, 3), 
    [r[r['dummy'] == 0]['after'].mean() for r in r_mixed], 
    yerr=[r[r['dummy'] == 0]['after'].std() for r in r_mixed], 
    color='r',
    )
# Out:
# <Container object of 5 artists>

# %% [markdown]
# ## Delay over time

# %%
r = r_mixed[0]
figure()
plot(r['before'][:100], 'o-')
show()

figure()
for r in r_mixed:
    plot(r['before'][:100], 'o')
show()

# %% [markdown]
# ## Delay distribution (before)

# %%
distrib_real = r[r['dummy'] == 0]['before'].copy()
distrib_real.sort()

distrib_dummy = r[r['dummy'] == 1]['before'].copy()
distrib_dummy.sort()

figure()
title('dummy messages')
plot(distrib_dummy, '-')
show()

figure()
title('real messages')
plot(distrib_real, '-')

figure()
title('dummy + adapted real messages')
plot(distrib_dummy, '-')
mapped_x_axis = np.array(range(len(distrib_real))) * len(distrib_dummy) / float(len(distrib_real))
plot(mapped_x_axis, distrib_real, '-')

show()

# %% [markdown]
# ## Delay distribution (after)

# %%
distrib_real = r[r['dummy'] == 0]['after'].copy()
distrib_real.sort()

distrib_dummy = r[r['dummy'] == 1]['after'].copy()
distrib_dummy.sort()

figure()
title('dummy messages')
plot(distrib_dummy, '-')
show()

figure()
title('real messages')
plot(distrib_real, '-')

figure()
title('dummy + adapted real messages')
plot(distrib_dummy, '-')
mapped_x_axis = np.array(range(len(distrib_real))) * len(distrib_dummy) / float(len(distrib_real))
plot(mapped_x_axis, distrib_real, '-')

show()

# %%
distrib_real = pd.DataFrame(r[r['dummy'] == 0]['before'].copy())
distrib_real.sort()
distrib_real['group'] = pd.cut(distrib_real, bins=[2, 4, 6, 8, 10])
#distrib_real.set_index(['group'], inplace=True)
#distrib_real.unstack('group')
distrib_real.groupby('group')
distrib_real
# Out:
#       before                               group
# 0   2.111389  Index([u'(2, 4]'], dtype='object')
# 1   4.319120  Index([u'(4, 6]'], dtype='object')
# 2   1.205698                                 NaN
# 3   0.301391                                 NaN
# 4   5.295894  Index([u'(4, 6]'], dtype='object')
# 5   0.732741                                 NaN
# 6   5.928878  Index([u'(4, 6]'], dtype='object')
# 7   1.802500                                 NaN
# 8   2.831070  Index([u'(2, 4]'], dtype='object')
# 9   7.009520  Index([u'(6, 8]'], dtype='object')
# 10  2.626015  Index([u'(2, 4]'], dtype='object')
# 11  1.600771                                 NaN
# 12  1.358870                                 NaN
# 13  0.145870                                 NaN
# 14  2.194921  Index([u'(2, 4]'], dtype='object')
# 15  0.862029                                 NaN
# 16  2.276660  Index([u'(2, 4]'], dtype='object')
# 17  1.897767                                 NaN
# 18  1.947132                                 NaN
# 19  0.077797                                 NaN
# 20  0.551199                                 NaN
# 21  0.421706                                 NaN
# 22  0.477007                                 NaN
# 23  4.732303  Index([u'(4, 6]'], dtype='object')
# 24  0.727069                                 NaN
# 25  0.383177                                 NaN
# 26  2.998682  Index([u'(2, 4]'], dtype='object')
# 27  0.379643                                 NaN
# 28  0.966704                                 NaN
# 29  1.638088                                 NaN
# 30  0.210979                                 NaN
# 31  0.580619                                 NaN
# 32  2.542582  Index([u'(2, 4]'], dtype='object')
# 33  0.083848                                 NaN
# 34  1.058502                                 NaN
# 35  2.892191  Index([u'(2, 4]'], dtype='object')
# 36  0.598319                                 NaN
# 37  0.725883                                 NaN
# 38  2.048593  Index([u'(2, 4]'], dtype='object')
# 39  0.858933                                 NaN
# 40  1.402034                                 NaN
# 41  0.386990                                 NaN
# 42  1.601983                                 NaN
# 43  1.435124                                 NaN
# 44  0.762121                                 NaN
# 45  1.272774                                 NaN
# 46  3.324308  Index([u'(2, 4]'], dtype='object')
# 47  1.233515                                 NaN
# 48  0.475573                                 NaN
# 49  0.265381                                 NaN
# 50  0.281369                                 NaN
# 51  0.122655                                 NaN
# 52  0.272212                                 NaN
# 53  0.915380                                 NaN
# 54  0.634024                                 NaN
# 55  0.137670                                 NaN
# 56  0.023255                                 NaN
# 57  3.610088  Index([u'(2, 4]'], dtype='object')
# 58  1.473837                                 NaN
# 59  2.220334  Index([u'(2, 4]'], dtype='object')
#          ...                                 ...
#
# [2000 rows x 2 columns]

# %% [markdown]
# # Analysis of the delay before a real message:
#
# * r = real message
# * d = dummy message
#
# probability that no dummy message has being sent yet * probability that a real message is being sent
#
# $$  $$

# %%
n = 100
p_r = 1./n
p_d = 1./n
acc = [
    i*p_r / (1 - i*p_d)
    for i in range(1, n)
    ]
#plot(acc)
