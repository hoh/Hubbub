# %%
from IPython.display import HTML
HTML('''<h1>Table of Contents</h1>

<ol>
    <li><a href='#Comparing-real-and-dummy-delays'>Comparison of delays between real and dummies</a></li>
</ol>
<hr/>''')
# Out:
# <h1>Table of Contents</h1>
#
# <ol>
#     <li><a href='#Comparing-real-and-dummy-delays'>Comparison of delays between real and dummies</a></li>
# </ol>
# <hr/>

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Large plots
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 16, 9

# %%
import numpy as np
import pandas as pd

# %%
from hubbub.generator.generator import Simulator
from hubbub.generator.heartbeat import HeartBeatSimulator
from hubbub.datasets.simulations import simple_log, gauss_log, SIMPLE_LOG as SIMPLE_LOG_SAMPLE
# Out:
# Warning: This tool is designed for Python 3.

# %%
#SIMPLE_LOG = SIMPLE_LOG_SAMPLE
SIMPLE_LOG_SAMPLE
# Out:
# [(datetime.datetime(2000, 1, 1, 0, 1, 1, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 2, 9, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 3, 2, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 4, 8, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 5, 3, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 6, 7, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 7, 4, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 8, 6, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 9, 5, 123456), 10),
#  (datetime.datetime(2000, 1, 1, 0, 10, 0, 123456), 10)]

# %%
# Generating "real" messages dataset:
SIMPLE_LOG = simple_log(n=2000)
#SIMPLE_LOG = gauss_log(n=200)
SIMPLE_LOG[:10]
# Out:
# [(datetime.datetime(2000, 1, 1, 0, 1, 4, 894096), 10),
#  (datetime.datetime(2000, 1, 1, 0, 1, 44, 778651), 10),
#  (datetime.datetime(2000, 1, 1, 0, 2, 14, 183786), 10),
#  (datetime.datetime(2000, 1, 1, 0, 3, 18, 931312), 10),
#  (datetime.datetime(2000, 1, 1, 0, 3, 20, 56831), 10),
#  (datetime.datetime(2000, 1, 1, 0, 3, 30, 430721), 10),
#  (datetime.datetime(2000, 1, 1, 0, 3, 46, 663569), 10),
#  (datetime.datetime(2000, 1, 1, 0, 3, 50, 178214), 10),
#  (datetime.datetime(2000, 1, 1, 0, 3, 58, 673814), 10),
#  (datetime.datetime(2000, 1, 1, 0, 5, 38, 911649), 10)]

# %% [markdown]
# # Running simulator

# %%
HeartBeatSimulator.period = 0.5
result_sm = Simulator(SIMPLE_LOG).run()
results_HB = [
    HeartBeatSimulator(SIMPLE_LOG).run() for i in xrange(5)
#    HeartBeatSimulator(SIMPLE_LOG).run(delay=lambda: 5) for i in xrange(10)
    ]

results_HB[0][:10]
# Out:
# [(datetime.datetime(2000, 1, 1, 0, 0), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 0, 44845), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 0, 86892), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 0, 531728), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 0, 846775), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 0, 945743), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 1, 189759), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 1, 341892), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 1, 490617), 10),
#  (datetime.datetime(2000, 1, 1, 0, 0, 1, 603053), 10)]

# %% [markdown]
# ## Converting results to timestamps for plotting:

# %%
import time
def timestamp(n):
    unix_time = time.mktime(n.timetuple()) + n.microsecond/1000000.
    return unix_time

# %%
r_real = pd.DataFrame(
    [(0, timestamp(i[0]), 'SIMPLE_LOG') for i in SIMPLE_LOG],
    columns=('dummy', 'timestamp', 'source'),
    )
r_real
# Out:
#     dummy     timestamp      source
# 0       0  9.466813e+08  SIMPLE_LOG
# 1       0  9.466813e+08  SIMPLE_LOG
# 2       0  9.466813e+08  SIMPLE_LOG
# 3       0  9.466814e+08  SIMPLE_LOG
# 4       0  9.466814e+08  SIMPLE_LOG
# 5       0  9.466814e+08  SIMPLE_LOG
# 6       0  9.466814e+08  SIMPLE_LOG
# 7       0  9.466814e+08  SIMPLE_LOG
# 8       0  9.466814e+08  SIMPLE_LOG
# 9       0  9.466815e+08  SIMPLE_LOG
# 10      0  9.466817e+08  SIMPLE_LOG
# 11      0  9.466817e+08  SIMPLE_LOG
# 12      0  9.466818e+08  SIMPLE_LOG
# 13      0  9.466818e+08  SIMPLE_LOG
# 14      0  9.466818e+08  SIMPLE_LOG
# 15      0  9.466818e+08  SIMPLE_LOG
# 16      0  9.466819e+08  SIMPLE_LOG
# 17      0  9.466820e+08  SIMPLE_LOG
# 18      0  9.466820e+08  SIMPLE_LOG
# 19      0  9.466820e+08  SIMPLE_LOG
# 20      0  9.466820e+08  SIMPLE_LOG
# 21      0  9.466821e+08  SIMPLE_LOG
# 22      0  9.466821e+08  SIMPLE_LOG
# 23      0  9.466821e+08  SIMPLE_LOG
# 24      0  9.466821e+08  SIMPLE_LOG
# 25      0  9.466821e+08  SIMPLE_LOG
# 26      0  9.466821e+08  SIMPLE_LOG
# 27      0  9.466821e+08  SIMPLE_LOG
# 28      0  9.466821e+08  SIMPLE_LOG
# 29      0  9.466822e+08  SIMPLE_LOG
# 30      0  9.466822e+08  SIMPLE_LOG
# 31      0  9.466823e+08  SIMPLE_LOG
# 32      0  9.466823e+08  SIMPLE_LOG
# 33      0  9.466824e+08  SIMPLE_LOG
# 34      0  9.466824e+08  SIMPLE_LOG
# 35      0  9.466824e+08  SIMPLE_LOG
# 36      0  9.466824e+08  SIMPLE_LOG
# 37      0  9.466824e+08  SIMPLE_LOG
# 38      0  9.466825e+08  SIMPLE_LOG
# 39      0  9.466825e+08  SIMPLE_LOG
# 40      0  9.466826e+08  SIMPLE_LOG
# 41      0  9.466827e+08  SIMPLE_LOG
# 42      0  9.466827e+08  SIMPLE_LOG
# 43      0  9.466828e+08  SIMPLE_LOG
# 44      0  9.466828e+08  SIMPLE_LOG
# 45      0  9.466828e+08  SIMPLE_LOG
# 46      0  9.466828e+08  SIMPLE_LOG
# 47      0  9.466829e+08  SIMPLE_LOG
# 48      0  9.466829e+08  SIMPLE_LOG
# 49      0  9.466829e+08  SIMPLE_LOG
# 50      0  9.466830e+08  SIMPLE_LOG
# 51      0  9.466831e+08  SIMPLE_LOG
# 52      0  9.466831e+08  SIMPLE_LOG
# 53      0  9.466832e+08  SIMPLE_LOG
# 54      0  9.466832e+08  SIMPLE_LOG
# 55      0  9.466832e+08  SIMPLE_LOG
# 56      0  9.466833e+08  SIMPLE_LOG
# 57      0  9.466833e+08  SIMPLE_LOG
# 58      0  9.466833e+08  SIMPLE_LOG
# 59      0  9.466833e+08  SIMPLE_LOG
#       ...           ...         ...
#
# [2000 rows x 3 columns]

# %%
r_dummyHB = [
    pd.DataFrame(
        [(1, timestamp(i[0]), 'HB{}'.format(index)) for i in r],
        columns=('dummy', 'timestamp', 'source'),
        )
    for index, r in enumerate(results_HB)
    ]
r_dummyHB[0]
# Out:
#     dummy     timestamp source
# 0       1  9.466812e+08    HB0
# 1       1  9.466812e+08    HB0
# 2       1  9.466812e+08    HB0
# 3       1  9.466812e+08    HB0
# 4       1  9.466812e+08    HB0
# 5       1  9.466812e+08    HB0
# 6       1  9.466812e+08    HB0
# 7       1  9.466812e+08    HB0
# 8       1  9.466812e+08    HB0
# 9       1  9.466812e+08    HB0
# 10      1  9.466812e+08    HB0
# 11      1  9.466812e+08    HB0
# 12      1  9.466812e+08    HB0
# 13      1  9.466812e+08    HB0
# 14      1  9.466812e+08    HB0
# 15      1  9.466812e+08    HB0
# 16      1  9.466812e+08    HB0
# 17      1  9.466812e+08    HB0
# 18      1  9.466812e+08    HB0
# 19      1  9.466812e+08    HB0
# 20      1  9.466812e+08    HB0
# 21      1  9.466812e+08    HB0
# 22      1  9.466812e+08    HB0
# 23      1  9.466812e+08    HB0
# 24      1  9.466812e+08    HB0
# 25      1  9.466812e+08    HB0
# 26      1  9.466812e+08    HB0
# 27      1  9.466812e+08    HB0
# 28      1  9.466812e+08    HB0
# 29      1  9.466812e+08    HB0
# 30      1  9.466812e+08    HB0
# 31      1  9.466812e+08    HB0
# 32      1  9.466812e+08    HB0
# 33      1  9.466812e+08    HB0
# 34      1  9.466812e+08    HB0
# 35      1  9.466812e+08    HB0
# 36      1  9.466812e+08    HB0
# 37      1  9.466812e+08    HB0
# 38      1  9.466812e+08    HB0
# 39      1  9.466812e+08    HB0
# 40      1  9.466812e+08    HB0
# 41      1  9.466812e+08    HB0
# 42      1  9.466812e+08    HB0
# 43      1  9.466812e+08    HB0
# 44      1  9.466812e+08    HB0
# 45      1  9.466812e+08    HB0
# 46      1  9.466812e+08    HB0
# 47      1  9.466812e+08    HB0
# 48      1  9.466812e+08    HB0
# 49      1  9.466812e+08    HB0
# 50      1  9.466812e+08    HB0
# 51      1  9.466812e+08    HB0
# 52      1  9.466812e+08    HB0
# 53      1  9.466812e+08    HB0
# 54      1  9.466812e+08    HB0
# 55      1  9.466812e+08    HB0
# 56      1  9.466812e+08    HB0
# 57      1  9.466812e+08    HB0
# 58      1  9.466812e+08    HB0
# 59      1  9.466812e+08    HB0
#       ...           ...    ...
#
# [345036 rows x 3 columns]

# %% [markdown]
# # Analyzing delays

# %% [markdown]
# ## Plotting

# %%
r = r_dummyHB[0]
figure()
plot(r['timestamp'][:100].diff(), 'o-')
show()

figure()
for r in r_dummyHB:
    plot(r['timestamp'][:100].diff(), 'o')
show()

# %%
r_mixed = [
    pd.concat((r_real, r))
    for r in r_dummyHB
]
for r in r_mixed:
    r.sort('timestamp', inplace=True)
    r['before'] = r['timestamp'].diff()
    r['after'] = -r['timestamp'].diff(periods=-1)

r_mixed[0].head(10)
# Out:
#    dummy     timestamp source    before     after
# 0      1  9.466812e+08    HB0       NaN  0.044845
# 1      1  9.466812e+08    HB0  0.044845  0.042047
# 2      1  9.466812e+08    HB0  0.042047  0.444836
# 3      1  9.466812e+08    HB0  0.444836  0.315047
# 4      1  9.466812e+08    HB0  0.315047  0.098968
# 5      1  9.466812e+08    HB0  0.098968  0.244016
# 6      1  9.466812e+08    HB0  0.244016  0.152133
# 7      1  9.466812e+08    HB0  0.152133  0.148725
# 8      1  9.466812e+08    HB0  0.148725  0.112436
# 9      1  9.466812e+08    HB0  0.112436  0.371804
#
# [10 rows x 5 columns]

# %% [markdown]
# ## Comparing real and dummy delays

# %%
print r_real['timestamp'][0]
r = r_mixed[0]
plot(r['before'])
r[r['dummy'] == 0].head(10)
# Out:
# 946681264.894
#    dummy     timestamp      source    before     after
# 0      0  9.466813e+08  SIMPLE_LOG  0.028673  0.112025
# 1      0  9.466813e+08  SIMPLE_LOG  0.500823  0.360558
# 2      0  9.466813e+08  SIMPLE_LOG  0.314373  0.147667
# 3      0  9.466814e+08  SIMPLE_LOG  0.261165  0.427473
# 4      0  9.466814e+08  SIMPLE_LOG  0.398453  0.504710
# 5      0  9.466814e+08  SIMPLE_LOG  0.147326  0.545276
# 6      0  9.466814e+08  SIMPLE_LOG  0.708164  0.073212
# 7      0  9.466814e+08  SIMPLE_LOG  0.086886  0.261148
# 8      0  9.466814e+08  SIMPLE_LOG  0.398441  0.286248
# 9      0  9.466815e+08  SIMPLE_LOG  0.212910  0.019297
#
# [10 rows x 5 columns]
# /Users/okso/Documents/Thesis/Hubbub/venv/lib/python2.7/site-packages/IPython/core/formatters.py:239: FormatterWarning: Exception in image/png formatter: Allocated too many blocks
#   FormatterWarning,

# %% [markdown]
# ## Delay before

# %%
# Average delay

if False:
    for r in r_mixed:
        print 'all  mean', r['before'].mean()
        print 'all  std ', r['before'].std()
        print 'dumm mean', r[r['dummy'] == 1]['before'].mean()
        print 'dumm std ', r[r['dummy'] == 1]['before'].std()
        print 'real mean', r[r['dummy'] == 0]['before'].mean()
        print 'real std ', r[r['dummy'] == 0]['before'].std()
        print

bar(
    range(0, len(r_mixed)*3, 3), 
    [r['before'].mean() for r in r_mixed], 
    yerr=[r['before'].std() for r in r_mixed], 
    color='g',
    )
    
bar(
    range(1, len(r_mixed)*3, 3), 
    [r[r['dummy'] == 1]['before'].mean() for r in r_mixed], 
    yerr=[r[r['dummy'] == 1]['before'].std() for r in r_mixed], 
    color='y',
    )

bar(
    range(2, len(r_mixed)*3, 3), 
    [r[r['dummy'] == 0]['before'].mean() for r in r_mixed], 
    yerr=[r[r['dummy'] == 0]['before'].std() for r in r_mixed], 
    color='r',
    )
# Out:
# <Container object of 5 artists>

# %% [markdown]
# ## Delay After

# %%
# Average delay

if False:
    for r in r_mixed:
        print 'all  mean', r['after'].mean()
        print 'all  std ', r['after'].std()
        print 'dumm mean', r[r['dummy'] == 1]['after'].mean()
        print 'dumm std ', r[r['dummy'] == 1]['after'].std()
        print 'real mean', r[r['dummy'] == 0]['after'].mean()
        print 'real std ', r[r['dummy'] == 0]['after'].std()
        print

bar(
    range(0, len(r_mixed)*3, 3), 
    [r['after'].mean() for r in r_mixed], 
    yerr=[r['after'].std() for r in r_mixed], 
    color='g',
    )
    
bar(
    range(1, len(r_mixed)*3, 3), 
    [r[r['dummy'] == 1]['after'].mean() for r in r_mixed], 
    yerr=[r[r['dummy'] == 1]['after'].std() for r in r_mixed], 
    color='y',
    )

bar(
    range(2, len(r_mixed)*3, 3), 
    [r[r['dummy'] == 0]['after'].mean() for r in r_mixed], 
    yerr=[r[r['dummy'] == 0]['after'].std() for r in r_mixed], 
    color='r',
    )
# Out:
# <Container object of 5 artists>

# %% [markdown]
# ## Delay over time

# %%
r = r_mixed[0]
figure()
plot(r['before'][:100], 'o-')
show()

figure()
for r in r_mixed:
    plot(r['before'][:100], 'o')
show()

# %% [markdown]
# ## Delay distribution (before)

# %%
distrib_real = r[r['dummy'] == 0]['before'].copy()
distrib_real.sort()

distrib_dummy = r[r['dummy'] == 1]['before'].copy()
distrib_dummy.sort()

figure()
title('dummy messages')
plot(distrib_dummy, '-')
show()

figure()
title('real messages')
plot(distrib_real, '-')

figure()
title('dummy + adapted real messages')
plot(distrib_dummy, '-')
mapped_x_axis = np.array(range(len(distrib_real))) * len(distrib_dummy) / float(len(distrib_real))
plot(mapped_x_axis, distrib_real, '-')

show()

# %% [markdown]
# ## Delay distribution (after)

# %%
distrib_real = r[r['dummy'] == 0]['after'].copy()
distrib_real.sort()

distrib_dummy = r[r['dummy'] == 1]['after'].copy()
distrib_dummy.sort()

figure()
title('dummy messages')
plot(distrib_dummy, '-')
show()

figure()
title('real messages')
plot(distrib_real, '-')

figure()
title('dummy + adapted real messages')
plot(distrib_dummy, '-')
mapped_x_axis = np.array(range(len(distrib_real))) * len(distrib_dummy) / float(len(distrib_real))
plot(mapped_x_axis, distrib_real, '-')

show()

# %%
distrib_real = pd.DataFrame(r[r['dummy'] == 0]['before'].copy())
distrib_real.sort()
distrib_real['group'] = pd.cut(distrib_real, bins=[2, 4, 6, 8, 10])
#distrib_real.set_index(['group'], inplace=True)
#distrib_real.unstack('group')
distrib_real.groupby('group')
distrib_real
# Out:
#       before  group
# 0   0.108406    NaN
# 1   0.201273    NaN
# 2   0.451304    NaN
# 3   0.041627    NaN
# 4   0.203224    NaN
# 5   0.096580    NaN
# 6   0.221832    NaN
# 7   0.066601    NaN
# 8   0.058474    NaN
# 9   0.157473    NaN
# 10  0.049318    NaN
# 11  0.437383    NaN
# 12  0.078751    NaN
# 13  0.643553    NaN
# 14  0.016730    NaN
# 15  0.580384    NaN
# 16  0.005769    NaN
# 17  0.440924    NaN
# 18  0.025752    NaN
# 19  0.173186    NaN
# 20  0.051873    NaN
# 21  0.398753    NaN
# 22  0.346498    NaN
# 23  0.295322    NaN
# 24  0.095357    NaN
# 25  0.150947    NaN
# 26  0.019859    NaN
# 27  0.140949    NaN
# 28  0.050715    NaN
# 29  0.605769    NaN
# 30  0.099298    NaN
# 31  0.384372    NaN
# 32  0.399845    NaN
# 33  0.031516    NaN
# 34  0.512419    NaN
# 35  0.131503    NaN
# 36  0.665848    NaN
# 37  0.458358    NaN
# 38  0.036944    NaN
# 39  0.003536    NaN
# 40  0.350107    NaN
# 41  0.177597    NaN
# 42  0.481753    NaN
# 43  0.062876    NaN
# 44  0.182556    NaN
# 45  0.046393    NaN
# 46  0.302335    NaN
# 47  0.137216    NaN
# 48  0.154550    NaN
# 49  0.110657    NaN
# 50  0.278868    NaN
# 51  0.186587    NaN
# 52  0.081967    NaN
# 53  0.245472    NaN
# 54  0.066388    NaN
# 55  0.118385    NaN
# 56  0.185020    NaN
# 57  0.128282    NaN
# 58  0.265091    NaN
# 59  0.058023    NaN
#          ...    ...
#
# [2000 rows x 2 columns]
